# %%
pip install dabl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached dabl-0.2.5-py3-none-any.whl (564 kB)
# ...
#   Using cached joblib-1.3.1-py3-none-any.whl (301 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn==1.2.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import dabl
import pandas as pd
import matplotlib.pyplot as plt
from dabl import plot

# %%
data = pd.read_csv('resume.csv')

# %%
data
# Out:
#        Unnamed: 0  index ключевая_спец спец_по_дипл  год_рожд город_обуч  \
# 0               0      0    прогр_комп   прогр_комп      1991     прочие
# 1               1      1    инжен_техн   прогр_комп      1987     прочие
# 2               2      2        физмат       физмат      1970     Москва
# 3               3      3     авиа_косм   инжен_техн      1964     Москва
# 4               4      4        физмат       физмат      1965     прочие
# ...           ...    ...           ...          ...       ...        ...
# 17611       17611  20073        физмат   инжен_техн      1988     Москва
# 17612       17612  20074     авиа_косм   инжен_техн      1996     Москва
# 17613       17613  20075     авиа_косм       физмат      1974     прочие
# 17614       17614  20076    прогр_комп   прогр_комп      1993     прочие
# 17615       17615  20078    инжен_техн   инжен_техн      1992     прочие
#
#           тип_вуза спец_по_вуз  выпуск  возраст_из_ВУЗа        работаю  \
# ...

# %%
data.drop('index', axis=1)
# Out:
#        Unnamed: 0 ключевая_спец спец_по_дипл  год_рожд город_обуч  \
# 0               0    прогр_комп   прогр_комп      1991     прочие
# 1               1    инжен_техн   прогр_комп      1987     прочие
# 2               2        физмат       физмат      1970     Москва
# 3               3     авиа_косм   инжен_техн      1964     Москва
# 4               4        физмат       физмат      1965     прочие
# ...           ...           ...          ...       ...        ...
# 17611       17611        физмат   инжен_техн      1988     Москва
# 17612       17612     авиа_косм   инжен_техн      1996     Москва
# 17613       17613     авиа_косм       физмат      1974     прочие
# 17614       17614    прогр_комп   прогр_комп      1993     прочие
# 17615       17615    инжен_техн   инжен_техн      1992     прочие
#
#           тип_вуза спец_по_вуз  выпуск  возраст_из_ВУЗа        работаю  \
# 0            проч.  прогр_комп    2013               22  разработчиком
# ...

# %%
plot(data.drop('index', axis=1), 'хочу_работать')
plt.show()
# Out:
# C:\Users\МП\AppData\Roaming\Python\Python39\site-packages\dabl\plot\supervised.py:622: FutureWarning: The second positional argument of plot is a Series 'y'. If passing a column name, use a keyword.
#   warnings.warn("The second positional argument of plot is a Series 'y'."
# Target looks like classification
# Linear Discriminant Analysis training set score: 0.264

# %%
plot(data.drop('index', axis=1), 'спец_по_дипл')
plt.show()
# Out:
# C:\Users\МП\AppData\Roaming\Python\Python39\site-packages\dabl\plot\supervised.py:622: FutureWarning: The second positional argument of plot is a Series 'y'. If passing a column name, use a keyword.
#   warnings.warn("The second positional argument of plot is a Series 'y'."
# Target looks like classification
# Linear Discriminant Analysis training set score: 0.317

# %%
plot(data, 'ключевая_спец')
plt.show()
# Out:
# C:\Users\МП\AppData\Roaming\Python\Python39\site-packages\dabl\plot\supervised.py:622: FutureWarning: The second positional argument of plot is a Series 'y'. If passing a column name, use a keyword.
#   warnings.warn("The second positional argument of plot is a Series 'y'."
# Target looks like classification
# Linear Discriminant Analysis training set score: 0.263

# %%
plot(data, 'спец_по_дипл')
plt.show()
# Out:
# C:\Users\МП\AppData\Roaming\Python\Python39\site-packages\dabl\plot\supervised.py:622: FutureWarning: The second positional argument of plot is a Series 'y'. If passing a column name, use a keyword.
#   warnings.warn("The second positional argument of plot is a Series 'y'."
# Target looks like classification
# Linear Discriminant Analysis training set score: 0.316

# %%
data.shape
# Out:
# (17616, 16)

# %%
data_clean = dabl.clean(data, verbose=0)

# %%
data_clean
# Out:
#          index ключевая_спец спец_по_дипл  год_рожд город_обуч     тип_вуза  \
# 0          0.0    прогр_комп   прогр_комп      1991     прочие        проч.
# 1          1.0    инжен_техн   прогр_комп      1987     прочие        проч.
# 2          2.0        физмат       физмат      1970     Москва     институт
# 3          3.0     авиа_косм   инжен_техн      1964     Москва  университет
# 4          4.0        физмат       физмат      1965     прочие  университет
# ...        ...           ...          ...       ...        ...          ...
# 17611  20073.0        физмат   инжен_техн      1988     Москва  университет
# 17612  20074.0     авиа_косм   инжен_техн      1996     Москва  университет
# 17613  20075.0     авиа_косм       физмат      1974     прочие  университет
# 17614  20076.0    прогр_комп   прогр_комп      1993     прочие  университет
# 17615  20078.0    инжен_техн   инжен_техн      1992     прочие  университет
#
# ...

# %%
types = dabl.detect_types(data_clean)
print(types)
# Out:
#                  continuous  dirty_float  low_card_int_ordinal  \
# index                  True        False                 False
# ключевая_спец         False        False                 False
# спец_по_дипл          False        False                 False
# год_рожд              False        False                  True
# город_обуч            False        False                 False
# тип_вуза              False        False                 False
# спец_по_вуз           False        False                 False
# выпуск                False        False                  True
# возраст_из_ВУЗа       False        False                  True
# работаю               False        False                 False
# живу                  False        False                 False
# Авто                  False        False                 False
# пол                   False        False                 False
# хочу_работать         False        False                 False
# ...

# %%
fc = dabl.SimpleClassifier(random_state=0)

# %%
X = data_clean.drop('хочу_работать', axis=1)
y = data_clean.хочу_работать

# %%
fc.fit(X, y)
# Out:
# C:\Users\МП\AppData\Roaming\Python\Python39\site-packages\sklearn\preprocessing\_encoders.py:808: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\МП\AppData\Roaming\Python\Python39\site-packages\sklearn\preprocessing\_encoders.py:808: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\МП\AppData\Roaming\Python\Python39\site-packages\sklearn\preprocessing\_encoders.py:808: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ...

# %%
ec = dabl.SimpleClassifier(random_state=0).fit(data_clean, target_col='хочу_работать')
# Out:
# C:\Users\МП\AppData\Roaming\Python\Python39\site-packages\sklearn\preprocessing\_encoders.py:808: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\МП\AppData\Roaming\Python\Python39\site-packages\sklearn\preprocessing\_encoders.py:808: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\МП\AppData\Roaming\Python\Python39\site-packages\sklearn\preprocessing\_encoders.py:808: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ...

# %%
dabl.explain(ec)
# Out:
# Depth: 5
# Number of leaves: 32
